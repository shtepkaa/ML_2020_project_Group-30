# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/Group30_Final_Project")
# !ls
# Out:
#  BHT_ARIMA
# 'BHTARIMA-ARIMA-Prophet-VAR_ele_1096_старые результаты.ipynb'
#  BHTARIMA-ARIMA-Prophet-VAR_traffic_40.ipynb
#  delete
#  ele_1096__.ipynb
#  ele_1096.ipynb
#  ele_40.ipynb
#  input
# 'M4 (1).ipynb'
#  m4_daily.ipynb
#  m4_hourly.ipynb
#  M4.ipynb
#  m4_monthly.ipynb
#  m4_quarterly.ipynb
#  m4_weekly.ipynb
#  m4_year.ipynb
#  M5.ipynb
#  models
#  output
#  __pycache__
#  traffic_80.ipynb
#  Untitled0.ipynb

# %%
# !pip install tensorly
# Out:
# ...
#      |████████████████████████████████| 71kB 2.4MB/s
# ...
#      |████████████████████████████████| 163kB 7.7MB/s
# ...
#   Created wheel for tensorly: filename=tensorly-0.4.5-cp36-none-any.whl size=100156 sha256=215857c81665172c8f72682000346ff83ab9b629fba9d7b4d7f64ac06d680c6c
#   Stored in directory: /root/.cache/pip/wheels/44/ae/02/8d00229a4fd0af192b48d24da903f9975c7ac10e706685fc39
# Successfully built tensorly
# ...

# %%
pip install pmdarima
# Out:
# ...
#      |████████████████████████████████| 1.5MB 2.8MB/s
# ...

# %%
from models.model_BHTARIMA import run_BHTARIMA 
from models.model_ARIMA import run_ARIMA
from models.model_Prophet import run_Prophet
#from models.model_VAR import run_VAR
from models.model_XGB import run_XGB

from input.datasets_from_paper.transform_traffic_80 import dataset_traffic_80, hyperparam_traffic_80
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import numpy as np

from statsmodels.tsa.api import VAR
from BHT_ARIMA.util.utility import get_acc, nrmse

def run_VAR(data):
  
      testsize = 0.1
      p = 1

      T = data.shape[-1]
      T_test = int((T * testsize) // 1)
      result_full = np.zeros([data.shape[0], T_test])

      total_time = 0
      n_round = 0

      for i in range(T_test):

        ts = (data[..., i:T-T_test+i].copy())
        n_round += 1
        model = VAR(ts)
        result = model.fit(p).forecast(ts, 1)
        result_full[..., i] = result[..., -1]

      label = data[..., -T_test:]

      stat = {}
      stat['acc'] = get_acc(result_full, label)
      stat['nrmse'] = nrmse(result_full, label)

      return(stat)

# %%
VAR_traffic_80 = run_VAR(dataset_traffic_80)
VAR_traffic_80
# Out:
# {'acc': 0.8921197640687645, 'nrmse': 0.14193640947117175}

# %%
BHTARIMA_traffic_80 = run_BHTARIMA(dataset_traffic_80, hyperparam_traffic_40['BHTARIMA'])
BHTARIMA_traffic_80
# Out:
# {'acc': 0.9995424171193882,
#  'ave_time': 1.3084405362606049,
#  'nrmse': 0.0006278946331649612}

# %%
ARIMA_traffic_80 = run_ARIMA(dataset_traffic_80, hyperparam_traffic_80['ARIMA'])
ARIMA_traffic_80
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# {'acc': 0.9995147412734734,
#  'ave_time': 58.06306818127632,
#  'nrmse': 0.0006572179168209609}

# %%
from models.model_Prophet import run_Prophet
Prophet_traffic_80 = run_Prophet(dataset_traffic_80, hyperparam_traffic_80['Prophet'])
Prophet_traffic_80
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# ...

# %%
test_size = dataset_traffic_80.shape[1] // 10
run_XGB(dataset_traffic_80, test_size)
# Out:
# [01:40:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:40:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:40:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:40:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:40:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:40:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:40:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...
